# %%
import matplotlib.pyplot as plt

df['type'].value_counts().plot(kind='bar')
plt.title("Movies vs TV Shows")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
df['type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Content Distribution")
plt.ylabel("")
plt.show()

# %%
df['release_year'].plot(kind='hist', bins=20)
plt.title("Release Year Distribution")
plt.xlabel("Release Year")
plt.show()

# %%
df['country'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Countries")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Insights
#
# 1. Movies dominate Netflix content.
# 2. USA has the highest number of shows and movies.
# 3. Most Netflix content was released after 2015.
# 4. Visualizations make data trends easier to understand.
